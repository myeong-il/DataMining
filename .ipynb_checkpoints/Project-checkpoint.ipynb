# %% [markdown]
# # 서울시 부동산 실거래가 이용하여 2년뒤 예측
# ### 2015 ~ 2020년 자치구별로 평균을 내어 정리한 후 그래프로 비교하고 시계열조사를 통하여 21~22년 어떻게 부동산 가격이 변화할지에 대해 알아 보았습니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import statsmodels.api as sm

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df2 = pd.read_csv("서울특별시 부동산 실거래가 정보.csv" , encoding = 'cp949')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2
# Out:
#                         실거래가아이디                 지번코드  시군구코드 자치구명       법정동코드  \
# 0        11440-2020-4-0007027-1           1144010800  11440  마포구  1144010800
# 1        11110-2020-4-0001450-1  1111017100100040000  11110  종로구  1111017100
# 2        11350-2020-4-0007054-1  1135010200105560000  11350  노원구  1135010200
# 3        11110-2020-4-0004943-1           1111016700  11110  종로구  1111016700
# 4        11305-2020-4-0005674-1           1130510200  11305  강북구  1130510200
# ...                         ...                  ...    ...  ...         ...
# 2247257  11500-2006-4-0031872-1  1150010400104480001  11500  강서구  1150010400
# 2247258  11500-2006-4-0031874-1  1150010200107010000  11500  강서구  1150010200
# 2247259  11500-2006-4-0031875-1           1150010800  11500  강서구  1150010800
# 2247260  11320-2005-4-0009356-1  1132010600107130000  11320  도봉구  1132010600
# 2247261  11170-2005-4-0007464-1  1117012400102310024  11170  용산구  1117012400
#
#           법정동명  신고년도  업무구분코드 업무구분  물건번호  대지권면적    건물면적 관리구분코드   층정보  건물주용도코드  \
# 0          대흥동  2020       4   신고     1   56.0   19.83      0   NaN     1001
# 1         명륜2가  2020       4   신고     1    0.0   84.90      0  12.0     2001
# 2          월계동  2020       4   신고     1    0.0   44.52      0   8.0     2001
# 3          충신동  2020       4   신고     1   67.1   44.39      0   NaN     1001
# 4           번동  2020       4   신고     1   88.6   45.59      0   NaN     1001
# ...        ...   ...     ...  ...   ...    ...     ...    ...   ...      ...
# 2247257    가양동  2006       4   신고     1    NaN   59.76      0   9.0     2001
# 2247258    등촌동  2006       4   신고     1    NaN   84.96      0   1.0     2001
# 2247259    공항동  2006       4   신고     1  139.0  240.64      0   NaN     1001
# 2247260    방학동  2005       4   신고     1    0.0   84.90      0  17.0     2001
# 2247261  한강로1가  2005       4   신고     1    0.0   85.95      0   1.0     2001
#
#         건물주용도       물건금액         건물명    건축년도
# 0        단독주택  680000000         NaN  1964.0
# 1         아파트  890000000         아남1  1995.0
# 2         아파트  320000000         주공2  1992.0
# 3        단독주택  220000000         NaN  1978.0
# 4        단독주택  287000000         NaN  1973.0
# ...       ...        ...         ...     ...
# 2247257   아파트  348000000     가양강나루현대  1999.0
# 2247258   아파트  420000000     진로미주아파트  1994.0
# 2247259  단독주택  410000000         NaN  1994.0
# 2247260   아파트  171000000  브라운스톤방학아파트  2003.0
# 2247261   아파트  112500000       삼각아파트  1970.0
#
# [2247262 rows x 19 columns]

# %%
df2.drop(['실거래가아이디', '지번코드', '업무구분코드', '업무구분',
          '물건번호', '관리구분코드', '층정보', '건물주용도코드',
          '건물명'], axis = 1, inplace = True)

# %%
df2
# Out:
#          시군구코드 자치구명       법정동코드   법정동명  신고년도  대지권면적    건물면적 건물주용도       물건금액  \
# 0        11440  마포구  1144010800    대흥동  2020   56.0   19.83  단독주택  680000000
# 1        11110  종로구  1111017100   명륜2가  2020    0.0   84.90   아파트  890000000
# 2        11350  노원구  1135010200    월계동  2020    0.0   44.52   아파트  320000000
# 3        11110  종로구  1111016700    충신동  2020   67.1   44.39  단독주택  220000000
# 4        11305  강북구  1130510200     번동  2020   88.6   45.59  단독주택  287000000
# ...        ...  ...         ...    ...   ...    ...     ...   ...        ...
# 2247257  11500  강서구  1150010400    가양동  2006    NaN   59.76   아파트  348000000
# 2247258  11500  강서구  1150010200    등촌동  2006    NaN   84.96   아파트  420000000
# 2247259  11500  강서구  1150010800    공항동  2006  139.0  240.64  단독주택  410000000
# 2247260  11320  도봉구  1132010600    방학동  2005    0.0   84.90   아파트  171000000
# 2247261  11170  용산구  1117012400  한강로1가  2005    0.0   85.95   아파트  112500000
#
#            건축년도
# 0        1964.0
# 1        1995.0
# 2        1992.0
# 3        1978.0
# 4        1973.0
# ...         ...
# 2247257  1999.0
# 2247258  1994.0
# 2247259  1994.0
# 2247260  2003.0
# 2247261  1970.0
#
# [2247262 rows x 10 columns]

# %%
df2.dtypes
# Out:
# 시군구코드      int64
# 자치구명      object
# 법정동코드      int64
# 법정동명      object
# 신고년도       int64
# 대지권면적    float64
# 건물면적     float64
# 건물주용도     object
# 물건금액       int64
# 건축년도     float64
# dtype: object

# %%
table = df2[df2['신고년도'] >= 2015]
table['신고년도'] = table['신고년도'].astype(str)
table
# Out:
# <ipython-input-8-de4aaf79d375>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table['신고년도'] = table['신고년도'].astype(str)
#          시군구코드 자치구명       법정동코드  법정동명  신고년도  대지권면적    건물면적 건물주용도        물건금액  \
# 0        11440  마포구  1144010800   대흥동  2020  56.00   19.83  단독주택   680000000
# 1        11110  종로구  1111017100  명륜2가  2020   0.00   84.90   아파트   890000000
# 2        11350  노원구  1135010200   월계동  2020   0.00   44.52   아파트   320000000
# 3        11110  종로구  1111016700   충신동  2020  67.10   44.39  단독주택   220000000
# 4        11305  강북구  1130510200    번동  2020  88.60   45.59  단독주택   287000000
# ...        ...  ...         ...   ...   ...    ...     ...   ...         ...
# 1067346  11680  강남구  1168010300   개포동  2015    NaN   50.38   아파트   940000000
# 1067347  11680  강남구  1168011800   도곡동  2015    NaN  114.99   아파트  1590000000
# 1067348  11680  강남구  1168010300   개포동  2015    NaN   35.87   아파트   685000000
# 1067349  11680  강남구  1168010600   대치동  2015  37.46   60.83  연립주택   420000000
# 1067350  11680  강남구  1168010100   역삼동  2015  56.23   73.36  연립주택   510000000
#
#            건축년도
# 0        1964.0
# 1        1995.0
# 2        1992.0
# 3        1978.0
# 4        1973.0
# ...         ...
# 1067346  1982.0
# 1067347  2006.0
# 1067348  1982.0
# 1067349  1994.0
# 1067350  1984.0
# 성북구   5.610105e+08
# 송파구   8.395177e+08
# 양천구   5.371161e+08
# 영등포구  6.642903e+08
# 용산구   1.075067e+09
# 은평구   4.042835e+08
# 종로구   6.351094e+08
# 중구    7.334200e+08
# 중랑구   4.408283e+08

# %%
div_table = pi_table/100000000 #단위 : 억원
div_table
# Out:
# 신고년도      2015      2016       2017       2018       2019       2020
# 자치구명
# 강남구   8.247352  9.179511  10.727897  11.996723  14.438571  13.663426
# 강동구   4.262044  4.599410   5.229899   5.524876   6.281904   6.222250
# 강북구   2.707382  2.880266   3.073916   3.339010   3.309038   3.641222
# 강서구   3.004286  3.406767   3.549379   3.935015   3.891968   4.555182
# 관악구   3.313313  3.539386   3.913477   4.480769   4.508922   4.915014
# 광진구   4.705267  4.860657   5.168810   6.047573   6.029154   6.539282
# 구로구   2.934265  3.146002   3.346886   3.699948   3.984697   4.266327
# 금천구   2.870435  3.246803   3.290451   3.539665   3.441223   3.670310
# 노원구   2.785011  3.028048   3.270961   3.707119   4.080847   4.719568
# 도봉구   2.518419  2.725390   2.909255   3.200175   3.283185   3.777353
# 동대문구  3.409553  3.754490   4.034084   4.518762   4.921178   5.760377
# 동작구   4.179439  4.941831   5.350208   6.031887   7.007896   7.516703
# 마포구   4.565209  4.872002   5.481013   6.148213   6.675653   7.283959
# 서대문구  3.697286  4.039734   4.302919   4.920793   5.421770   5.907105
# 서초구   8.084437  8.926335   9.824742  11.127588  12.677360  12.591377
# 성동구   5.074958  5.638586   6.450384   7.616120   9.008756  10.195071
# 성북구   3.660663  3.920442   4.213493   4.455338   4.904554   5.610105
# 송파구   5.501306  6.095607   6.709499   7.394103   9.068520   8.395177
# 양천구   3.911782  4.183991   4.635010   5.042959   5.955675   5.371161
# 영등포구  3.924870  4.400196   4.955115   5.627107   6.311445   6.642903
# 용산구   6.697684  7.829726   8.611880   9.346510  10.356242  10.750674
# 은평구   2.695202  3.002862   3.193912   3.605222   3.700011   4.042835
# 종로구   4.585166  4.908090   4.936407   5.697887   6.044058   6.351094
# 중구    5.059382  5.349599   5.585255   6.060366   6.995033   7.334200
# 중랑구   3.130134  3.418631   3.570219   4.052841   4.077815   4.408283

# %%
x = div_table.index
y1 = div_table['2015']
y2 = div_table['2016']
y3 = div_table['2017']
y4 = div_table['2018']
y5 = div_table['2019']
y6 = div_table['2020']

plt.plot(x,y1, label = '2015', marker = "o", color = 'b')
plt.plot(x,y2, label = '2016', marker = "*", color = 'c')
plt.plot(x,y3, label = '2017', marker = '<', color = 'r')
plt.plot(x,y4, label = '2018', marker = '+', color = 'm')
plt.plot(x,y5, label = '2019', marker = '>', color = 'g')
plt.plot(x,y6, label = '2020', marker = 'x', color = 'k')
plt.legend()
plt.xlabel('년도')
plt.ylabel('가격(단위 : 억 원)')
plt.title('서울시 년도별 부동산 실거래가 평균 그래프')
plt.xticks(rotation = 90)
plt.ylim(2, 16)
plt.show()

# %%
t = np.arange(2015,2021)
money = pd.pivot_table(table, values='물건금액', index = ['신고년도'],
                       columns = ['자치구명'], aggfunc=np.mean)
money = round((money / 100000000),2) #단위 : 억원
money
# Out:
# 자치구명    강남구   강동구   강북구   강서구   관악구   광진구   구로구   금천구   노원구   도봉구  ...    성동구  \
# 신고년도                                                               ...
# 2015   8.25  4.26  2.71  3.00  3.31  4.71  2.93  2.87  2.79  2.52  ...   5.07
# 2016   9.18  4.60  2.88  3.41  3.54  4.86  3.15  3.25  3.03  2.73  ...   5.64
# 2017  10.73  5.23  3.07  3.55  3.91  5.17  3.35  3.29  3.27  2.91  ...   6.45
# 2018  12.00  5.52  3.34  3.94  4.48  6.05  3.70  3.54  3.71  3.20  ...   7.62
# 2019  14.44  6.28  3.31  3.89  4.51  6.03  3.98  3.44  4.08  3.28  ...   9.01
# 2020  13.66  6.22  3.64  4.56  4.92  6.54  4.27  3.67  4.72  3.78  ...  10.20
#
# 자치구명   성북구   송파구   양천구  영등포구    용산구   은평구   종로구    중구   중랑구
# 신고년도
# 2015  3.66  5.50  3.91  3.92   6.70  2.70  4.59  5.06  3.13
# 2016  3.92  6.10  4.18  4.40   7.83  3.00  4.91  5.35  3.42
# 2017  4.21  6.71  4.64  4.96   8.61  3.19  4.94  5.59  3.57
# 2018  4.46  7.39  5.04  5.63   9.35  3.61  5.70  6.06  4.05
# 2019  4.90  9.07  5.96  6.31  10.36  3.70  6.04  7.00  4.08
# 2020  5.61  8.40  5.37  6.64  10.75  4.04  6.35  7.33  4.41
#
# [6 rows x 25 columns]

# %%
Predict = pd.DataFrame(index = [2021, 2022])
y_pred_df = pd.DataFrame()
error_df = pd.DataFrame()
abs_error_df = pd.DataFrame()
pct_error_df = pd.DataFrame()
sq_error_df = pd.DataFrame()
merror_df = pd.DataFrame(columns = ['me', 'mae', 'mape', 'mse'], index = money.columns)

# %%
for i in range(0,len(money.columns)):
    y = money.iloc[:,i]
    x = t
    x = sm.add_constant(x)
    model = sm.OLS(y,x).fit()
    print(model.summary())
    test_data = [2021, 2022]
    Predict[money.columns[i]] = model.predict(sm.add_constant(test_data))
    y_pred = model.predict(x)
    error = y - y_pred
    abs_error = np.abs(error)
    pct_error = (abs_error / y) * 100
    sq_error = error**2
    me = round(error.mean(),2)
    mae = round(abs_error.mean(),2)
    mape = round(pct_error.mean(),2)
    mse = round(sq_error.mean(),2)
    y_pred_df[money.columns[i]] = (y_pred)
    error_df[money.columns[i]] = (error)
    abs_error_df[money.columns[i]] = (abs_error)
    pct_error_df[money.columns[i]] = (pct_error)
    sq_error_df[money.columns[i]] = (sq_error)
    merror_df.iloc[i,:] = [me, mae, mape, mse]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    강남구   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     50.00
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):            0.00211
# Time:                        02:26:52   Log-Likelihood:                -5.5346
# No. Observations:                   6   AIC:                             15.07
# Df Residuals:                       4   BIC:                             14.65
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2530.6733    359.508     -7.039      0.002   -3528.827   -1532.520
# x1             1.2600      0.178      7.071      0.002       0.765       1.755
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.586
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.478
# Skew:                           0.692   Prob(JB):                        0.787
# Kurtosis:                       2.998   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    강동구   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     89.94
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000690
# Time:                        02:26:52   Log-Likelihood:                 2.6456
# No. Observations:                   6   AIC:                            -1.291
# Df Residuals:                       4   BIC:                            -1.708
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -866.7848     91.962     -9.425      0.001   -1122.113    -611.457
# x1             0.4323      0.046      9.484      0.001       0.306       0.559
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.871
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.378
# Skew:                           0.529   Prob(JB):                        0.828
# Kurtosis:                       2.374   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    강북구   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     94.30
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000629
# Time:                        02:26:52   Log-Likelihood:                 8.1309
# No. Observations:                   6   AIC:                            -12.26
# Df Residuals:                       4   BIC:                            -12.68
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -354.8038     36.861     -9.625      0.001    -457.147    -252.460
# x1             0.1774      0.018      9.711      0.001       0.127       0.228
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.213
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.213
# Skew:                          -0.441   Prob(JB):                        0.899
# Kurtosis:                       2.731   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    강서구   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     52.29
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):            0.00194
# Time:                        02:26:52   Log-Likelihood:                 3.7296
# No. Observations:                   6   AIC:                            -3.459
# Df Residuals:                       4   BIC:                            -3.876
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -551.3757     76.762     -7.183      0.002    -764.503    -338.249
# x1             0.2751      0.038      7.231      0.002       0.170       0.381
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.072
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.713
# Skew:                          -0.814   Prob(JB):                        0.700
# Kurtosis:                       2.550   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    관악구   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     129.4
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000341
# Time:                        02:26:52   Log-Likelihood:                 5.3662
# No. Observations:                   6   AIC:                            -6.732
# Df Residuals:                       4   BIC:                            -7.149
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -660.5105     58.437    -11.303      0.000    -822.757    -498.264
# x1             0.3294      0.029     11.373      0.000       0.249       0.410
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.819
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.484
# Skew:                           1.214   Prob(JB):                        0.476
# Kurtosis:                       3.204   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    광진구   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     62.74
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):            0.00137
# Time:                        02:26:52   Log-Likelihood:                 2.2313
# No. Observations:                   6   AIC:                           -0.4627
# Df Residuals:                       4   BIC:                           -0.8792
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -774.9243     98.536     -7.864      0.001   -1048.503    -501.346
# x1             0.3869      0.049      7.921      0.001       0.251       0.522
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.910
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.576
# Skew:                           0.612   Prob(JB):                        0.750
# Kurtosis:                       2.103   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    구로구   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     579.9
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           1.76e-05
# Time:                        02:26:52   Log-Likelihood:                 11.004
# No. Observations:                   6   AIC:                            -18.01
# Df Residuals:                       4   BIC:                            -18.42
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -546.3495     22.835    -23.926      0.000    -609.750    -482.949
# x1             0.2726      0.011     24.082      0.000       0.241       0.304
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.604
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.905
# Skew:                          -0.951   Prob(JB):                        0.636
# Kurtosis:                       3.059   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    금천구   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     22.72
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):            0.00887
# Time:                        02:26:52   Log-Likelihood:                 5.3808
# No. Observations:                   6   AIC:                            -6.762
# Df Residuals:                       4   BIC:                            -7.178
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -274.4952     58.294     -4.709      0.009    -436.346    -112.644
# x1             0.1377      0.029      4.766      0.009       0.057       0.218
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.496
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.562
# Skew:                           0.011   Prob(JB):                        0.755
# Kurtosis:                       1.501   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    노원구   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     121.3
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000386
# Time:                        02:26:52   Log-Likelihood:                 4.3448
# No. Observations:                   6   AIC:                            -4.690
# Df Residuals:                       4   BIC:                            -5.106
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -759.5914     69.282    -10.964      0.000    -951.949    -567.234
# x1             0.3783      0.034     11.016      0.000       0.283       0.474
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.340
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.687
# Skew:                           0.396   Prob(JB):                        0.709
# Kurtosis:                       1.544   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    도봉구   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     99.91
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000563
# Time:                        02:26:52   Log-Likelihood:                 6.6070
# No. Observations:                   6   AIC:                            -9.214
# Df Residuals:                       4   BIC:                            -9.630
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -471.9071     47.520     -9.931      0.001    -603.843    -339.972
# x1             0.2354      0.024      9.995      0.001       0.170       0.301
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.597
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.186
# Skew:                          -0.370   Prob(JB):                        0.911
# Kurtosis:                       2.557   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   동대문구   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     108.9
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000476
# Time:                        02:26:52   Log-Likelihood:                 2.9792
# No. Observations:                   6   AIC:                            -1.958
# Df Residuals:                       4   BIC:                            -2.375
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -903.4767     86.988    -10.386      0.000   -1144.994    -661.959
# x1             0.4500      0.043     10.437      0.000       0.330       0.570
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.515
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.657
# Skew:                           0.427   Prob(JB):                        0.720
# Kurtosis:                       1.621   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    동작구   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     382.0
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           4.04e-05
# Time:                        02:26:52   Log-Likelihood:                 4.3192
# No. Observations:                   6   AIC:                            -4.638
# Df Residuals:                       4   BIC:                            -5.055
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1353.9567     69.577    -19.460      0.000   -1547.133   -1160.780
# x1             0.6740      0.034     19.544      0.000       0.578       0.770
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.374
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.530
# Skew:                          -0.096   Prob(JB):                        0.767
# Kurtosis:                       1.557   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    마포구   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     517.4
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           2.21e-05
# Time:                        02:26:52   Log-Likelihood:                 6.3260
# No. Observations:                   6   AIC:                            -8.652
# Df Residuals:                       4   BIC:                            -9.068
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1126.8438     49.798    -22.628      0.000   -1265.105    -988.582
# x1             0.5614      0.025     22.746      0.000       0.493       0.630
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.992
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.217
# Skew:                           0.023   Prob(JB):                        0.897
# Kurtosis:                       2.070   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   서대문구   R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     262.8
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           8.47e-05
# Time:                        02:26:52   Log-Likelihood:                 5.5987
# No. Observations:                   6   AIC:                            -7.197
# Df Residuals:                       4   BIC:                            -7.614
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -906.6186     56.216    -16.127      0.000   -1062.699    -750.538
# x1             0.4517      0.028     16.211      0.000       0.374       0.529
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.497
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.926
# Skew:                          -0.962   Prob(JB):                        0.629
# Kurtosis:                       2.986   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    서초구   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     103.3
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000528
# Time:                        02:26:52   Log-Likelihood:                -1.9907
# No. Observations:                   6   AIC:                             7.981
# Df Residuals:                       4   BIC:                             7.565
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2013.3024    199.155    -10.109      0.001   -2566.246   -1460.358
# x1             1.0031      0.099     10.162      0.001       0.729       1.277
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.381
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.463
# Skew:                           0.665   Prob(JB):                        0.793
# Kurtosis:                       2.712   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    성동구   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     195.7
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000152
# Time:                        02:26:52   Log-Likelihood:               -0.37648
# No. Observations:                   6   AIC:                             4.753
# Df Residuals:                       4   BIC:                             4.336
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2121.4190    152.179    -13.940      0.000   -2543.935   -1698.903
# x1             1.0551      0.075     13.989      0.000       0.846       1.265
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.102
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.501
# Skew:                           0.068   Prob(JB):                        0.779
# Kurtosis:                       1.591   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    성북구   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     80.98
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000844
# Time:                        02:26:52   Log-Likelihood:                 3.2691
# No. Observations:                   6   AIC:                            -2.538
# Df Residuals:                       4   BIC:                            -2.955
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -741.4386     82.886     -8.945      0.001    -971.566    -511.311
# x1             0.3697      0.041      8.999      0.001       0.256       0.484
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.299
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.462
# Skew:                           0.321   Prob(JB):                        0.794
# Kurtosis:                       1.802   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    송파구   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):            0.00470
# Time:                        02:26:52   Log-Likelihood:                -3.2052
# No. Observations:                   6   AIC:                             10.41
# Df Residuals:                       4   BIC:                             9.994
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1381.4214    243.841     -5.665      0.005   -2058.432    -704.410
# x1             0.6883      0.121      5.695      0.005       0.353       1.024
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.780
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.183
# Skew:                           1.077   Prob(JB):                        0.553
# Kurtosis:                       3.303   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    양천구   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     19.99
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):             0.0111
# Time:                        02:26:52   Log-Likelihood:               -0.97392
# No. Observations:                   6   AIC:                             5.948
# Df Residuals:                       4   BIC:                             5.531
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -746.8129    168.112     -4.442      0.011   -1213.566    -280.060
# x1             0.3726      0.083      4.471      0.011       0.141       0.604
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.562
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.487
# Skew:                           0.697   Prob(JB):                        0.784
# Kurtosis:                       3.075   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   영등포구   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     575.5
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           1.79e-05
# Time:                        02:26:52   Log-Likelihood:                 6.5398
# No. Observations:                   6   AIC:                            -9.080
# Df Residuals:                       4   BIC:                            -9.496
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1147.5471     48.055    -23.880      0.000   -1280.969   -1014.125
# x1             0.5714      0.024     23.990      0.000       0.505       0.638
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.223
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.483
# Skew:                           0.508   Prob(JB):                        0.785
# Kurtosis:                       2.052   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    용산구   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     310.9
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           6.08e-05
# Time:                        02:26:52   Log-Likelihood:                 2.5505
# No. Observations:                   6   AIC:                            -1.101
# Df Residuals:                       4   BIC:                            -1.517
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1638.4995     93.432    -17.537      0.000   -1897.908   -1379.091
# x1             0.8166      0.046     17.632      0.000       0.688       0.945
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.164
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.631
# Skew:                          -0.328   Prob(JB):                        0.730
# Kurtosis:                       1.554   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    은평구   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     254.0
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           9.06e-05
# Time:                        02:26:52   Log-Likelihood:                 8.7315
# No. Observations:                   6   AIC:                            -13.46
# Df Residuals:                       4   BIC:                            -13.88
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -528.0938     33.350    -15.835      0.000    -620.688    -435.500
# x1             0.2634      0.017     15.936      0.000       0.218       0.309
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.512
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.496
# Skew:                           0.653   Prob(JB):                        0.780
# Kurtosis:                       2.471   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    종로구   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     86.07
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000751
# Time:                        02:26:52   Log-Likelihood:                 3.4473
# No. Observations:                   6   AIC:                            -2.895
# Df Residuals:                       4   BIC:                            -3.311
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -741.0533     80.459     -9.210      0.001    -964.445    -517.662
# x1             0.3700      0.040      9.278      0.001       0.259       0.481
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.467
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                2.709
# Skew:                          -1.592   Prob(JB):                        0.258
# Kurtosis:                       3.832   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     중구   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     78.88
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000888
# Time:                        02:26:52   Log-Likelihood:                 1.6344
# No. Observations:                   6   AIC:                            0.7312
# Df Residuals:                       4   BIC:                            0.3147
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -960.6057    108.843     -8.826      0.001   -1262.802    -658.410
# x1             0.4791      0.054      8.881      0.001       0.329       0.629
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.608
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.649
# Skew:                          -0.269   Prob(JB):                        0.723
# Kurtosis:                       1.480   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    중랑구   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     130.0
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):           0.000338
# Time:                        02:26:52   Log-Likelihood:                 6.9611
# No. Observations:                   6   AIC:                            -9.922
# Df Residuals:                       4   BIC:                            -10.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -506.9390     44.796    -11.317      0.000    -631.313    -382.565
# x1             0.2531      0.022     11.401      0.000       0.191       0.315
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.453
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.734
# Skew:                           0.845   Prob(JB):                        0.693
# Kurtosis:                       2.718   Cond. No.                     2.38e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i
# 2017  0.000278  0.008926  1.451247e-07  0.001401  0.001365  0.038640
# 2018  0.000044  0.002286  8.640145e-03  0.005995  0.041461  0.087955
# 2019  1.376711  0.078347  1.310480e-02  0.061362  0.009179  0.012163
# 2020  0.751111  0.045106  1.451247e-03  0.021651  0.000232  0.000165
#
#                구로구       금천구       노원구       도봉구  ...       성동구       성북구  \
# 신고년도                                              ...
# 2015  2.313152e-03  0.016653  0.018418  0.001488  ...  0.141519  0.015447
# 2016  2.003628e-05  0.012823  0.000007  0.000173  ...  0.011871  0.000212
# 2017  5.936336e-03  0.000241  0.019841  0.001788  ...  0.125383  0.004244
# 2018  1.451247e-07  0.016335  0.006264  0.000151  ...  0.057235  0.034172
# 2019  6.098866e-05  0.012079  0.007644  0.020490  ...  0.009143  0.013127
# 2020  6.369615e-04  0.000310  0.030376  0.014745  ...  0.053119  0.050947
#
#            송파구       양천구      영등포구       용산구       은평구       종로구        중구  \
# 신고년도
# 2015  0.000661  0.000073  0.001488  0.036827  0.000218  0.008711  0.037194
# 2016  0.003915  0.012353  0.002794  0.014768  0.000476  0.001878  0.000014
# 2017  0.019841  0.000562  0.004133  0.007217  0.002665  0.088011  0.055427
# 2018  0.022244  0.000014  0.001176  0.000070  0.011015  0.008711  0.059815
# 2019  0.709927  0.303758  0.020408  0.040727  0.004689  0.004011  0.046780
# 2020  0.265961  0.169273  0.009716  0.050518  0.000066  0.000011  0.004508
#
#                중랑구
# 신고년도
# 2015  1.907029e-04
# 2016  5.311927e-04
# 2017  6.415247e-03
# 2018  2.153906e-02
# 2019  5.834050e-03
# 2020  2.267574e-07
#
# [6 rows x 25 columns]

# %%
merror_df
# Out:
#      me   mae  mape   mse
# 자치구명
# 강남구   0   0.4  3.05  0.37
# 강동구  -0  0.12  2.17  0.02
# 강북구  -0  0.04  1.32     0
# 강서구  -0  0.11  2.79  0.02
# 관악구  -0  0.08   1.8  0.01
# 광진구  -0  0.14  2.61  0.03
# 구로구  -0  0.03  0.81     0
# 금천구  -0  0.09  2.62  0.01
# 노원구  -0   0.1  2.87  0.01
# 도봉구  -0  0.06   1.9  0.01
# 동대문구 -0  0.13  2.96  0.02
# 동작구   0   0.1  1.75  0.01
# 마포구  -0  0.07  1.33  0.01
# 서대문구 -0  0.07   1.6  0.01
# 서초구  -0  0.26  2.24  0.11
# 성동구   0  0.23  3.55  0.07
# 성북구  -0  0.12  2.64  0.02
# 송파구  -0  0.29  3.51  0.17
# 양천구  -0  0.18   3.4  0.08
# 영등포구 -0  0.07  1.31  0.01
# 용산구  -0  0.14  1.59  0.03
# 은평구  -0  0.04  1.31     0
# 종로구  -0   0.1  1.94  0.02
# 중구   -0  0.16  2.69  0.03
# 중랑구  -0  0.06  1.48  0.01

# %% [markdown]
# # 서울시 비만도 데이터를 이용하여 년도별 평균 비만, 저체중, 정상 비율과 실거래가를 소득기준으로 하여 소득기준과의 상관계수 분석
#
# ### 2015 ~ 2019년도 서울시의 년도별 비만, 저체중, 정상 비율을 평균내고 2020 ~ 2022년까지 시계열 조사로 예측한후 위에서 조사한 부동산 실거래가를 소득기준으로 판단하여 비만도 데이터와 합쳐 연관성을 분석하겠습니다.

# %%
fat_rate = pd.read_csv("서울시 비만도.txt", sep="\t")
fat_rate.rename(columns = {'비만(BMI≥25)' : '비만', '저체중(BMI<18.5)' : '저체중',
                           "정상(18.5≤BMI＜25)" : "정상",
                           "체질량지수(BMI)(평균)" : "BMI평균"},
                inplace=True)

# %%
fat_rate
# Out:
#        기간  자치구    비만  저체중    정상  BMI평균
# 0    2015  종로구  25.0  6.5  68.5   23.2
# 1    2015   중구  23.6  5.0  71.4   23.1
# 2    2015  용산구  24.7  5.6  69.7   23.1
# 3    2015  성동구  24.1  5.3  70.6   23.0
# 4    2015  광진구  24.5  5.3  70.2   23.1
# ..    ...  ...   ...  ...   ...    ...
# 120  2019  관악구  35.1  5.6  59.3   23.7
# 121  2019  서초구  25.1  8.3  66.6   22.9
# 122  2019  강남구  28.6  6.4  65.0   23.3
# 123  2019  송파구  27.9  4.6  67.6   23.4
# 124  2019  강동구  31.3  5.5  63.2   23.7
#
# [125 rows x 6 columns]

# %%
fat_table = round(fat_rate.groupby('기간').mean() ,2)
fat_table
# Out:
#          비만   저체중     정상  BMI평균
# 기간
# 2015  24.95  5.63  69.42  23.06
# 2016  25.84  5.63  68.53  23.17
# 2017  25.94  5.58  68.48  23.23
# 2018  31.44  5.36  63.20  23.62
# 2019  31.86  5.18  62.95  23.67

# %%
fat_table.drop('BMI평균', axis = 1, inplace=True)
t = np.arange(2015,2020)

fat_Predict = pd.DataFrame(index = [2020, 2021, 2022]

# %%
fat_y_pred_df = pd.DataFrame()
fat_error_df = pd.DataFrame()
fat_abs_error_df = pd.DataFrame()
fat_pct_error_df = pd.DataFrame()
fat_sq_error_df = pd.DataFrame()
fat_merror_df = pd.DataFrame(columns = ['me', 'mae', 'mape', 'mse'], index = fat_table.columns)
for i in range(0,len(fat_table.columns)):
    y = fat_table.iloc[:,i]
    x = t
    x = sm.add_constant(x)
    model = sm.OLS(y,x).fit()
    print(model.summary())
    test_data = [2020, 2021, 2022]
    fat_Predict[fat_table.columns[i]] = model.predict(sm.add_constant(test_data))
    y_pred = model.predict(x) 
    error = y - y_pred
    abs_error = np.abs(error)
    pct_error = (abs_error / y) * 100
    sq_error = error**2
    me = round((error.mean() * 10000000000000),2)
    mae = round(abs_error.mean(),2)
    mape = round(pct_error.mean(),2)
    mse = round(sq_error.mean(),2)
    fat_y_pred_df[money.columns[i]] = (y_pred)
    fat_error_df[money.columns[i]] = (error)
    fat_abs_error_df[money.columns[i]] = (abs_error)
    fat_pct_error_df[money.columns[i]] = (pct_error)
    fat_sq_error_df[money.columns[i]] = (sq_error)
    fat_merror_df.iloc[i,:] = [me, mae, mape, mse]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     비만   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     15.65
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):             0.0288
# Time:                        02:38:42   Log-Likelihood:                -8.0171
# No. Observations:                   5   AIC:                             20.03
# Df Residuals:                       3   BIC:                             19.25
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3889.0080    990.255     -3.927      0.029   -7040.441    -737.575
# x1             1.9420      0.491      3.956      0.029       0.380       3.504
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.693
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.383
# Skew:                          -0.568   Prob(JB):                        0.826
# Kurtosis:                       2.261   Cond. No.                     2.88e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    저체중   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     18.31
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):             0.0234
# Time:                        02:38:42   Log-Likelihood:                 6.4223
# No. Observations:                   5   AIC:                            -8.845
# Df Residuals:                       3   BIC:                            -9.626
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        241.4650     55.152      4.378      0.022      65.947     416.983
# x1            -0.1170      0.027     -4.279      0.023      -0.204      -0.030
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.460
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.400
# Skew:                           0.283   Prob(JB):                        0.819
# Kurtosis:                       1.735   Cond. No.                     2.88e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     정상   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                     14.99
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):             0.0305
# Time:                        02:38:42   Log-Likelihood:                -7.8188
# No. Observations:                   5   AIC:                             19.64
# Df Residuals:                       3   BIC:                             18.86
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3751.5750    951.747      3.942      0.029     722.691    6780.459
# x1            -1.8270      0.472     -3.872      0.030      -3.329      -0.325
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.762
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.324
# Skew:                           0.500   Prob(JB):                        0.850
# Kurtosis:                       2.254   Cond. No.                     2.88e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:70: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
fat_Predict_merge = pd.concat([fat_table,fat_Predict])
fat_Predict_merge
# Out:
#           비만    저체중      정상
# 2015  24.950  5.630  69.420
# 2016  25.840  5.630  68.530
# 2017  25.940  5.580  68.480
# 2018  31.440  5.360  63.200
# 2019  31.860  5.180  62.950
# 2020  33.832  5.125  61.035
# 2021  35.774  5.008  59.208
# 2022  37.716  4.891  57.381

# %%
Income_standard = []

# %%
for i in range(0,len(Predict_merge.index)):
    Income_standard.append(round(Predict_merge.iloc[i,:].mean(),3))

# %%
fat_Predict_merge['소득기준'] = Income_standard

# %%
fat_Predict_merge
# Out:
#           비만    저체중      정상   소득기준
# 2015  24.950  5.630  69.420  4.221
# 2016  25.840  5.630  68.530  4.636
# 2017  25.940  5.580  68.480  5.053
# 2018  31.440  5.360  63.200  5.646
# 2019  31.860  5.180  62.950  6.255
# 2020  33.832  5.125  61.035  6.566
# 2021  35.774  5.008  59.208  7.113
# 2022  37.716  4.891  57.381  7.604

# %%
fat_Predict_merge.corr()
# Out:
#             비만       저체중        정상      소득기준
# 비만    1.000000 -0.988149 -0.999957  0.982602
# 저체중  -0.988149  1.000000  0.986687 -0.988802
# 정상   -0.999957  0.986687  1.000000 -0.981484
# 소득기준  0.982602 -0.988802 -0.981484  1.000000

# %% [markdown]
# # 결론
# ### 소득기준과 비만은 양의 상관관계를 가지고 있고, 저체중과 정상 비율은 음의 상관관계를 가지고 있습니다. 즉 소득기준이 증가할수록 비만율도 증가하고, 저체중과 정상비율은 감소하는 관계를 나타내고 있습니다.
